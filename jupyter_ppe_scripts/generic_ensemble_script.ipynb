# %% [markdown]
# <h1> Ensemble generation submission and analysis notebook </h1>
#
# This script uses a combination of bash and python cells to form a workflow for creating and analysing FATES (or any CLM) ensembles. It will:
#
# <ol>
# <li>Clone the github repo
# <li>Make and build a default 4x5 CLM-FATES case
# <li>Make an ensemble of CLM-FATES cases
# <li>Generate an ensemble of parameter files with one at a time or latin hypercube  modification
# <li>Point each ensemble member at a different parameter file
# <li>Submit all these jobs
# <li>Analyse output
# </ol>
#
# n.b. This notebook is also set up to work with Cheyenne specific paths, but can be modified.
#
# The version here is relatively simple in that it just submits a one at a time sensemble and plots maps of the output. Obviously much more can be made of the ensemble design and analysis but this is here as a generic tool...

# %% [markdown]
# #### INITIALISE: Control variables for the analysis script.

# %%
# This mega script does 
# ensemble setup (including parameter file generation.  
# job submission and 
# analysis. 

# You can turn these off and on according to where you are tin the process. 

dosetup = 0 #do we want to create parameters files and so on?
dosubmit = 0 #do we do the submission stage, or just the analysis?
forcenewcase = 0 #do we scurb all the old cases and start again?
doanalysis = 1 #do we want to plot the outputs? 
print("setup, submit, analysis:", dosetup,dosubmit,doanalysis)
# Out:
# setup, submit, analysis: 0 0 1

# %% [markdown]
# #### INITIALISE: Define parameter space for senstivity analysis.

# %%
#aspiration to make this into a dictionary...
n=1 #the number of the ensemble. For when you need to do it all again ;) 
sp=1 #are we using SP mode?
parameter_list=['fates_rad_leaf_clumping_index','fates_rad_leaf_xl',
                'fates_rad_leaf_rhovis','fates_rad_stem_rhovis',
                'fates_rad_leaf_tauvis','fates_rad_stem_tauvis' ,
               'fates_vai_top_bin_width','fates_vai_width_increase_factor']
parameter_label=['clumping_index','leaf_xl',
                'leaf_rhovis','stem_rhovis',
                'leaf_tauvis','stem_tauvis' ,
               'top_bin_width','width_increase_factor']
nparams = 8
#how many members are in the ensemble?
ncases=nparams*2
min_delta=[0.5,   0.01,0.75, 0.75, 0.75,0.75, 0.25, 1.1]
max_delta=[1/0.85,1.4 ,1.25, 1.25, 1.25,1.25, 0.5, 1.25]
print(parameter_list)
# Out:
# ['fates_rad_leaf_clumping_index', 'fates_rad_leaf_xl', 'fates_rad_leaf_rhovis', 'fates_rad_stem_rhovis', 'fates_rad_leaf_tauvis', 'fates_rad_stem_tauvis', 'fates_vai_top_bin_width', 'fates_vai_width_increase_factor']

# %% [markdown]
# #### INITIALISE: Import libraries

# %%
import os
import netCDF4 as nc4
import sys
import shutil
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import xarray as xr
from matplotlib import pyplot as plt
#import datetime

# %% [markdown]
# #### INITIALISE: Set pathnames for parameter directories and casenames.

# %%
# what is your clone of the ctsm repo called? (or you want it to be called?) 
ctsmrepo='ctsmsep22'

#what do you want the directory with the ensemble cases in to be called?
ens_directory='RTM_ens'+str(n)

#what do you want the case names to begin with?
caseroot=ens_directory+'_case_'

USER='rfisher'

#path to scratch (or where the model is built.)
defbuildroot='/glade/scratch/'

#path to scratch (or where the model is built.)
output_dir='/glade/scratch/'+USER+'/'

#where are we now?
notebookdr=os.getcwd() 

# git directory. aka where do you want the code and scripts to live?
gitpath = '/glade/work/'+USER+'/'

# some more derived path names to simplify latter scripts
scriptsdir='/glade/work/'+USER+'/git/'+ctsmrepo+'/cime/scripts/'

# %% [markdown]
# #### INITIALISE: SP/NOCOMP specific paths to default case/param files

# %%
if(sp == 1): #Settings for the SP ensemble.
    resub=0 #how many times to resubmit the model. 

    #what is the name of your 'basecase'?
    defcase='fates_crops_smo_minlai_opt_vcmax50'
    
    #what is the base parameter file called?
    paramfiledefault='fates_params_default.nc'    

else: #Settings for the NOCOMP ensemble. 
    resub=2 #how many times do we want to resubmit the job?
    
    #what is the name of your 'basecase'?
    defcase='SPdefault_sept'
    
    #what is the base parameter file called?
    paramfiledefault='fates_params_default.nc'   
    
#set up the parameter file paths even if not in 'setup' mode
paramsdir = scriptsdir+'/'+ens_directory+'/parameter_files'
defparamfile=gitpath+'/'+ctsmrepo+'/src/fates/parameter_files/'+paramfiledefault
fatesparamfile='fates_params_'+ens_directory+'_'

# %% [markdown]
# #### INITIALISE: Make a function that creates directories if they don't already exist

# %%
def make_directory(fileroot):   
    if(os.path.isdir(fileroot)):
        print('dir exists:'+fileroot)
    else:
        os.mkdir(fileroot)
        print('made: '+fileroot)

# %% [markdown]
# #### SETUP: Make a git repo if needed.

# %%
make_directory(gitpath+'git')
# Out:
# dir exists:/glade/work/rfisher/git

# %% [markdown]
# #### SETUP: Clone CTSM repo (if necessary). BASH

# %%
# %%bash -s "$ctsmrepo" "$dosetup"
# ctsmrepo=$1
# dosetup=$2
#
# if [ $dosetup -eq 1 ]
# then
# cd /glade/work/$USER/git
# #go to git directory
# pwd
# #go to git repo, or checkout code
# if [[ -d "$ctsmrepo" ]]
# then
# cd $ctsmrepo
# echo "Already have ctsm repo"
# else
# echo "Cloning ctsm"
# #clone CTSM code if you didn't to this already.
# git clone https://github.com/escomp/ctsm $ctsmrepo
# cd $ctsmrepo
# ./manage_externals/checkout_externals
# cd src
# fi
# fi

# %% [markdown]
# #### SETUP: Make a default FATES 4x5 case BASH

# %%
# %%bash -s "$scriptsdir" "$dosetup" "$defcase"
# scriptsdir=$1
# dosetup=$2
# defcase=$3
# echo "defcase is" $defcase
# echo "setup=" $dosetup
# echo $dosetup
# compset=2000_DATM%GSWP3v1_CLM50%FATES_SICE_SOCN_MOSART_SGLC_SWAV_SESP
# if [[ $dosetup -eq 1 ]]
# then
# cd $scriptsdir
# if [[ -d "$defcase" ]]
# then
#     echo "$defcase exists on your filesystem." .$defcase
# else
#     echo "making defcase.",$defcase
# ./create_newcase --case $defcase --compset 2000_DATM%GSWP3v1_CLM50%FATES_SICE_SOCN_MOSART_SGLC_SWAV_SESP --res f45_f45_mg37  --run-unsupported
# cd $defcase
# ./case.setup
# ./case.build
# fi
# fi
# echo "Currently in" $(pwd)
# Out:
# defcase is fates_crops_smo_minlai_opt_vcmax50
# setup= 0
# 0
# Currently in /glade/u/home/rfisher/fates_sp_ensembles

# %% [markdown]
# #### SETUP: Adjust settings of default case. BASH

# %%
# %%bash -s "$scriptsdir" "$defcase" "$dosetup"
#
# scriptsdir=$1
# defcase=$2
# dosetup=$3
#
# if [[ $dosetup -eq 1 ]]
# then
# defbld=$defbuildroot$USER/$defcase/bld
# cd $scriptsdir$defcase
#
# echo 'updating settings'
# ./xmlchange CONTINUE_RUN=FALSE;
# ./xmlchange --id STOP_N --val 5;  #number of years of simulation
# ./xmlchange --id STOP_OPTION --val nyears;
# ./xmlchange --id CLM_FORCE_COLDSTART --val on;
# echo "Currently in" $(pwd)
# fi

# %% [markdown]
# #### SETUP: Make ensemble and parameter directory

# %%
make_directory(scriptsdir+ens_directory)
make_directory(scriptsdir+ens_directory+'/parameter_files' )
# Out:
# dir exists:/glade/work/rfisher/git/ctsmsep22/cime/scripts/RTM_ens1
# dir exists:/glade/work/rfisher/git/ctsmsep22/cime/scripts/RTM_ens1/parameter_files

# %% [markdown]
# #### SETUP: Make ensemble of CLM cases BASH

# %%
# %%bash -s "$scriptsdir" "$defcase" "$dosetup" "$ens_directory" "$caseroot" "$ncases" "$forcenewcase"
#
# scriptsdir=$1
# defcase=$2
# dosetup=$3
# ens_directory=$4
# caseroot=$5
# ncases=$6
# forcenewcase=$7
#
# echo "ncases=" $ncases
# echo "caseroot=" $caseroot
# echo "dosetup=" $dosetup
# echo "forcenewcase=" $forcenewcase
# echo "ens_directory=" $ens_directory
#
# if [[ $dosetup -eq 1 ]]
# then
# cd $scriptsdir
#
# counter1=12 #include a default zero case.
# while [ $counter1 -le $ncases ]
# do
#   newcase=$caseroot$counter1 #name of ensemble membr case.
#   if [ -d $ens_directory/$newcase ]
#   then
#     echo ' new case already exists',$ens_directory/$newcase
#     if [ $forcenewcase -eq 1 ]
#     then
#     echo 'force making case', $ens_directory/$newcase
#     rm -rf $ens_directory/$newcase
#     ./create_clone --clone $defcase --case $ens_directory/$newcase ;
#     cd $ens_directory/$newcase
#     echo 'case setup', $ens_directory/$newcase
#     ./case.setup;
#      cd ../../
#     fi
#   else
#    echo 'making new case', $ens_directory/$newcase
#     ./create_clone --clone $defcase --case $ens_directory/$newcase ;
#     cd $ens_directory/$newcase
#     echo 'case setup', $ens_directory/$newcase
#     ./case.setup;
#     cd ../../
#   fi
# ((counter1++))
# done
#
# fi
# Out:
# ncases= 16
# caseroot= RTM_ens1_case_
# dosetup= 0
# forcenewcase= 0
# ens_directory= RTM_ens1

# %% [markdown]
# #### SETUP: Create .nc version of current defualt file. I FAILED ATT THIS. NEEDS INPUT..
# You currently have to do this step manually, by doing this in the terminal:
#
# <i> cd /glade/work/$USER/git/$ctsmrepo/src/fates/parameter_files/</i><br>
# <i>ncgen -o fates_params_default.nc fates_params_default.cdl </i>

# %% [markdown]
# #### SETUP: Copy default template parameter file to ensemble parameter directory

# %%
if(dosetup == 1): 
    filename_template = paramsdir+'/'+paramfiledefault
    try:
        os.remove(filename_template)
    except:
        print('file does not yet exist: '+filename_template)
    shutil.copy(defparamfile,filename_template)
    print('default parameters in'+filename_template)

# %% [markdown]
# #### SETUP: Make a default user_nl_clm file

# %%
if (dosetup == 1 ):
    defcasedir = scriptsdir+'/'+defcase #where is the vanilla file?
    os.chdir(defcasedir) #go to the def case dir
    if(os.path.isfile('/user_nl_clm_store')):
        #move the stored version to the default version
        shutil.copy(user_nl_clm_store, user_nl_clm_default)
    else:
        #store the 'vanilla' user_nl_clm file
        shutil.copy('user_nl_clm', 'user_nl_clm_store')
        # and then make a copy of that to act as the default for the ensemble. 
        shutil.copy('user_nl_clm_store', 'user_nl_clm_default')
        
    #write configuration and dummy parameter filename into new file. 
    f = open('user_nl_clm_default', 'a')
    if (sp ==1): #change to SP mode. 
        f.write('use_fates_sp = true')
        f.write('\n')
    f.write('fates_paramfile = "nullparameterfile"')
    f.close()
    # copy this 'fresh' default file into the ensemble directory. 
    shutil.copy('user_nl_clm_default', scriptsdir+'/'+ens_directory+'/user_nl_clm_default')
    
    #check what you made!
    #os.system("cat user_nl_clm_default")
    os.chdir(notebookdr)
print('end')
# Out:
# end

# %% [markdown]
# #### SETUP: Create ensemble of parameter files

# %%
if(dosetup == 1): 
    fatesparamfile= 'fates_params_'+ens_directory+'_'
    vs=range(0,ncases+1) 
    for i in vs:
        filename_out = paramsdir+'/'+fatesparamfile+str(i)+'.nc' 
        #print('make:'+filename_out)
        try:
            os.remove(filename_out)
        except:
            print('file does not yet exist: '+filename_out)
        shutil.copy(filename_template,filename_out)
print('end')
# Out:
# end

# %% [markdown]
# #### SETUP: Make function to modify FATES parameter files.

# %%
def def_pftfile( fileroot,i,variable,delta):   
    pfilename = fileroot+str(i)+'.nc' 
    fin = nc4.Dataset(pfilename, 'r+')
    print('modifying parameter file',i,variable,delta);
    var = fin.variables[variable]
    var[:] = var[:]*delta
    fin.close()

# %% [markdown]
# #### SETUP: Modify parameter files (one at a time)

# %%
if(dosetup == 1): 
    fileroot =  paramsdir+'/'+fatesparamfile 
    if(sp == 1):
        for p in range(0,8):
            def_pftfile(fileroot,p*2+1,parameter_list[p],min_delta[p])
            def_pftfile(fileroot,p*2+2,parameter_list[p],max_delta[p])

# %% [markdown]
# #### SETUP: Point each ensemble script at different parameter file

# %%
if(dosetup == 1): 
    root= scriptsdir+'/'+ens_directory+'/'
    vs=range(0,ncases+1) 
    print('paramsdir=',paramsdir)
    for i in vs:
        pftfilename = paramsdir+'/'+fatesparamfile+str(i)+'.nc'    
        print(fatesparamfile+str(i)+'.nc')
 
        unlfile=root+caseroot+str(i)+'/'+'user_nl_clm'
        defunl=scriptsdir+'/'+ens_directory+'/user_nl_clm_default' 
        print(defunl)
        shutil.copy(defunl,unlfile)
        print('unl='+unlfile)   
        fin = open(unlfile, "rt")     
        data = fin.read()   #read file contents to string   
        data = data.replace('nullparameterfile',pftfilename) #replace all occurrences of the required string        
        fin.close() #close the input file       
        fin = open(unlfile, "wt") #open the input file in write mode     
        fin.write(data) #overrite the input file with the resulting data       
        fin.close() #close the file
# !cat '/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/RTM_ens1_case_14/user_nl_clm'
# Out:
# r2i0n20
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_14.nc"

# %% [markdown]
# #### SETUP: Check parameter files were correctly modifed

# %%
i=15
paramnum=7
pf= paramsdir+'/'+fatesparamfile+str(0)+'.nc' 
print(pf)
find = nc4.Dataset(pf, 'r+')
vardef=find.variables[parameter_list[paramnum]]
pf= paramsdir+'/'+fatesparamfile+str(i)+'.nc' 
print(pf)
finm = nc4.Dataset(pf, 'r+')
varmod=finm.variables[parameter_list[paramnum]]
print('actual ratio:',np.divide(varmod[:],vardef[:]))
print('target ratio:',min_delta[paramnum])
# Out:
# /glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_0.nc
# /glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_15.nc
# actual ratio: 1.1
# target ratio: 1.1

# %% [markdown]
# #### SUBMISSION: Submit ensemble of cases BASH

# %%
# %%bash -s "$scriptsdir" "$defcase" "$ens_directory" "$caseroot" "$ncases" "$dosubmit"
#
# scriptsdir=$1
# defcase=$2
# ens_directory=$3
# caseroot=$4
# ncases=$5
# dosubmit=$6
# echo $dosubmit
# if [ $dosubmit -eq 1 ]
# then
# cd $scriptsdir
#
# echo 'submitting'
# startcase=12
# counter1=$startcase
# cd $ens_directory
# pwd
#
# while [ $counter1 -le $ncases ]
# do
#   echo $counter1
#   newcase=$caseroot$counter1
#   echo $newcase
#
#   if [ -d $newcase ]
#   then
#     cd $newcase
#     cat user_nl_clm
#     echo 'submitting job',$newcase
#     ./xmlchange BUILD_COMPLETE=TRUE
#     #./xmlchange RESUBMIT=1
#    # ./xmlchange PROJECT=P93300041
#     ./case.submit
#     cd ../
#   else
#    echo 'no case', $newcase
#   fi
#
#   ((counter1++))
#   done
# else
# echo "not submitting jobs"
# fi
# Out:
# 1
# submitting
# /glade/work/rfisher/git/ctsmsep22/cime/scripts/RTM_ens1
# 12
# RTM_ens1_case_12
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_12.nc"submitting job,RTM_ens1_case_12
# For your changes to take effect, run:
# ./case.build --clean-all
# ./case.build
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.st_archive
# Creating file case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2022-10-10 07:43:58 atm
# Create namelist for component datm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cdeps/datm/cime_config/buildnml
#   2022-10-10 07:43:59 lnd
# Create namelist for component clm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2022-10-10 07:43:59 ice
# Create namelist for component sice
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2022-10-10 07:43:59 ocn
# Create namelist for component socn
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2022-10-10 07:43:59 rof
# Create namelist for component mosart
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/mosart//cime_config/buildnml
#   2022-10-10 07:44:00 glc
# Create namelist for component sglc
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2022-10-10 07:44:00 wav
# Create namelist for component swav
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2022-10-10 07:44:00 esp
# Create namelist for component sesp
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2022-10-10 07:44:00 cpl
# Create namelist for component drv
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runconfig for components ['CPL', 'ATM', 'LND', 'ROF']
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300641 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 6818877.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q share -l walltime=00:20:00 -A P93300641  -W depend=afterok:6818877.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 6818878.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 6818877.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 6818878.chadmin1.ib0.cheyenne.ucar.edu
# 13
# RTM_ens1_case_13
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_13.nc"submitting job,RTM_ens1_case_13
# For your changes to take effect, run:
# ./case.build --clean-all
# ./case.build
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.st_archive
# Creating file case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2022-10-10 07:44:07 atm
# Create namelist for component datm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cdeps/datm/cime_config/buildnml
#   2022-10-10 07:44:07 lnd
# Create namelist for component clm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2022-10-10 07:44:07 ice
# Create namelist for component sice
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2022-10-10 07:44:07 ocn
# Create namelist for component socn
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2022-10-10 07:44:07 rof
# Create namelist for component mosart
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/mosart//cime_config/buildnml
#   2022-10-10 07:44:07 glc
# Create namelist for component sglc
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2022-10-10 07:44:07 wav
# Create namelist for component swav
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2022-10-10 07:44:07 esp
# Create namelist for component sesp
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2022-10-10 07:44:07 cpl
# Create namelist for component drv
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runconfig for components ['CPL', 'ATM', 'LND', 'ROF']
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300641 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 6818879.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q share -l walltime=00:20:00 -A P93300641  -W depend=afterok:6818879.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 6818880.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 6818879.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 6818880.chadmin1.ib0.cheyenne.ucar.edu
# 14
# RTM_ens1_case_14
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_14.nc"submitting job,RTM_ens1_case_14
# For your changes to take effect, run:
# ./case.build --clean-all
# ./case.build
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.st_archive
# Creating file case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2022-10-10 07:44:12 atm
# Create namelist for component datm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cdeps/datm/cime_config/buildnml
#   2022-10-10 07:44:12 lnd
# Create namelist for component clm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2022-10-10 07:44:12 ice
# Create namelist for component sice
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2022-10-10 07:44:12 ocn
# Create namelist for component socn
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2022-10-10 07:44:12 rof
# Create namelist for component mosart
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/mosart//cime_config/buildnml
#   2022-10-10 07:44:12 glc
# Create namelist for component sglc
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2022-10-10 07:44:12 wav
# Create namelist for component swav
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2022-10-10 07:44:12 esp
# Create namelist for component sesp
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2022-10-10 07:44:12 cpl
# Create namelist for component drv
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runconfig for components ['CPL', 'ATM', 'LND', 'ROF']
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300641 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 6818881.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q share -l walltime=00:20:00 -A P93300641  -W depend=afterok:6818881.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 6818882.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 6818881.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 6818882.chadmin1.ib0.cheyenne.ucar.edu
# 15
# RTM_ens1_case_15
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_15.nc"submitting job,RTM_ens1_case_15
# For your changes to take effect, run:
# ./case.build --clean-all
# ./case.build
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.st_archive
# Creating file case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2022-10-10 07:44:17 atm
# Create namelist for component datm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cdeps/datm/cime_config/buildnml
#   2022-10-10 07:44:17 lnd
# Create namelist for component clm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2022-10-10 07:44:17 ice
# Create namelist for component sice
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2022-10-10 07:44:17 ocn
# Create namelist for component socn
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2022-10-10 07:44:17 rof
# Create namelist for component mosart
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/mosart//cime_config/buildnml
#   2022-10-10 07:44:17 glc
# Create namelist for component sglc
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2022-10-10 07:44:17 wav
# Create namelist for component swav
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2022-10-10 07:44:17 esp
# Create namelist for component sesp
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2022-10-10 07:44:17 cpl
# Create namelist for component drv
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runconfig for components ['CPL', 'ATM', 'LND', 'ROF']
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300641 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 6818883.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q share -l walltime=00:20:00 -A P93300641  -W depend=afterok:6818883.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 6818884.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 6818883.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 6818884.chadmin1.ib0.cheyenne.ucar.edu
# 16
# RTM_ens1_case_16
# !----------------------------------------------------------------------------------
# ! Users should add all user specific namelist changes below in the form of
# ! namelist_var = new_namelist_value
# !
# ! EXCEPTIONS:
# ! Set use_cndv           by the compset you use and the CLM_BLDNML_OPTS -dynamic_vegetation setting
# ! Set use_vichydro       by the compset you use and the CLM_BLDNML_OPTS -vichydro           setting
# ! Set use_cn             by the compset you use and CLM_BLDNML_OPTS -bgc  setting
# ! Set use_crop           by the compset you use and CLM_BLDNML_OPTS -crop setting
# ! Set spinup_state       by the CLM_BLDNML_OPTS -bgc_spinup      setting
# ! Set co2_ppmv           with CCSM_CO2_PPMV                      option
# ! Set fatmlndfrc         with LND_DOMAIN_PATH/LND_DOMAIN_FILE    options
# ! Set finidat            with RUN_REFCASE/RUN_REFDATE/RUN_REFTOD options for hybrid or branch cases
# !                        (includes $inst_string for multi-ensemble cases)
# !                        or with CLM_FORCE_COLDSTART to do a cold start
# !                        or set it with an explicit filename here.
# ! Set maxpatch_glc       with GLC_NEC                            option
# ! Set glc_do_dynglacier  with GLC_TWO_WAY_COUPLING               env variable
# !----------------------------------------------------------------------------------
#
# use_fates_sp = true
# fates_paramfile = "/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/parameter_files/fates_params_RTM_ens1_16.nc"submitting job,RTM_ens1_case_16
# For your changes to take effect, run:
# ./case.build --clean-all
# ./case.build
# env_batch.xml appears to have changed, regenerating batch scripts
# manual edits to these file will be lost!
# Creating batch scripts
# Writing case.run script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /glade/work/rfisher/git/ctsmsep22/ccs_config/machines/template.st_archive
# Creating file case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2022-10-10 07:44:21 atm
# Create namelist for component datm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cdeps/datm/cime_config/buildnml
#   2022-10-10 07:44:21 lnd
# Create namelist for component clm
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../cime_config/buildnml
# WARNING: CLM is starting up from a cold state
#   2022-10-10 07:44:21 ice
# Create namelist for component sice
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2022-10-10 07:44:21 ocn
# Create namelist for component socn
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2022-10-10 07:44:21 rof
# Create namelist for component mosart
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/mosart//cime_config/buildnml
#   2022-10-10 07:44:21 glc
# Create namelist for component sglc
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2022-10-10 07:44:21 wav
# Create namelist for component swav
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2022-10-10 07:44:21 esp
# Create namelist for component sesp
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/CIME/non_py/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2022-10-10 07:44:21 cpl
# Create namelist for component drv
#    Calling /glade/work/rfisher/git/ctsmsep22/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runconfig for components ['CPL', 'ATM', 'LND', 'ROF']
# Checking that inputdata is available as part of case submission
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Loading input file list: 'Buildconf/mosart.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Submitting job script qsub -q regular -l walltime=12:00:00 -A P93300641 -v ARGS_FOR_SCRIPT='--resubmit' .case.run
# Submitted job id is 6818885.chadmin1.ib0.cheyenne.ucar.edu
# Submit job case.st_archive
# Submitting job script qsub -q share -l walltime=00:20:00 -A P93300641  -W depend=afterok:6818885.chadmin1.ib0.cheyenne.ucar.edu -v ARGS_FOR_SCRIPT='--resubmit' case.st_archive
# Submitted job id is 6818886.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.run with id 6818885.chadmin1.ib0.cheyenne.ucar.edu
# Submitted job case.st_archive with id 6818886.chadmin1.ib0.cheyenne.ucar.edu

# %% [markdown]
# <h2>Analyse output</h2>

# %% [markdown]
# ### Paths for analysis

# %%
if doanalysis ==1: 
    output='/glade/scratch/rfisher/'
    conv = 3600*24*365
    yr='.clm2.h0.'   
    ychoose=2001
    delta=1
    print('ychoose=', ychoose)
    rel=1
# Out:
# ychoose= 2001

# %% [markdown]
# #### ANALYSIS: Choose variables to read in

# %%
vars=['FATES_GPP','FSR','SABV','SABG','lat','lon','time']

# %% [markdown]
#  #### ANALYSIS: Make output figure directory

# %%
figpath = (notebookdr+ 'figs_'+ens_directory)
make_directory(figpath)
# Out:
# dir exists:/glade/u/home/rfisher/fates_sp_ensemblesfigs_RTM_ens1

# %% [markdown]
# ####  ANALYSIS: Make a single data structure for the ensemble

# %%
ychoose=2003
print(output_dir)
if doanalysis ==1:
    debug=0
    hstring='.clm2.h0.'
    vs=range(0,ncases+1)
    count=1
    print(caseroot)
    print(vs)

    for i in vs:       
        run=caseroot+str(i)
        os.listdir(output_dir + '/archive')
        arc = output_dir + 'archive/' + run + '/lnd/hist/' 
        hpath = arc
        tfile = run+hstring+str(ychoose)+'-01.nc'
        if(os.path.isdir(hpath)): 
            #print('is archive')
            if(os.path.isfile(hpath+tfile)): 
                if debug == 1 :print('file in archive')
            else:
                if debug == 1 :print('file not in archive',hpath+tfile)
        else:
            if(debug == 1):print('no archive')
            hpath = output_dir + run + '/run/'            
            if(os.path.isdir(hpath)): 
                print('is rundir',hpath)                
                if(os.path.isfile(hpath+tfile)):
                    if debug == 1 :print('file in  rundir')
                else:
                    print('no file in  rundir',hpath+tfile)
            else:
                print('no  rundir',hpath)
        if debug == 1 :print(hpath)   
        allvars=list(xr.open_dataset(hpath +run+hstring+str(ychoose)+'-01.nc', decode_times=False).variables)
        dropvars=list(set(allvars) - set(vars)) #thanks to Ben for figuring this part out :) 
        print('file'+str(i)+' ='+hpath +run+hstring+str(ychoose)+'-01.nc')
        tmp=xr.open_mfdataset(arc +run+hstring+str(ychoose)+'*', decode_times=False, drop_variables=dropvars)

        if i==0:
            dsc = tmp           
        else:
            dsc=xr.concat([dsc,tmp],'ens')

print('end')
# Out:
# /glade/scratch/rfisher/
# RTM_ens1_case_
# range(0, 17)
# file0 =/glade/scratch/rfisher/archive/RTM_ens1_case_0/lnd/hist/RTM_ens1_case_0.clm2.h0.2003-01.nc
# file1 =/glade/scratch/rfisher/archive/RTM_ens1_case_1/lnd/hist/RTM_ens1_case_1.clm2.h0.2003-01.nc
# file2 =/glade/scratch/rfisher/archive/RTM_ens1_case_2/lnd/hist/RTM_ens1_case_2.clm2.h0.2003-01.nc
# file3 =/glade/scratch/rfisher/archive/RTM_ens1_case_3/lnd/hist/RTM_ens1_case_3.clm2.h0.2003-01.nc
# file4 =/glade/scratch/rfisher/archive/RTM_ens1_case_4/lnd/hist/RTM_ens1_case_4.clm2.h0.2003-01.nc
# file5 =/glade/scratch/rfisher/archive/RTM_ens1_case_5/lnd/hist/RTM_ens1_case_5.clm2.h0.2003-01.nc
# file6 =/glade/scratch/rfisher/archive/RTM_ens1_case_6/lnd/hist/RTM_ens1_case_6.clm2.h0.2003-01.nc
# file7 =/glade/scratch/rfisher/archive/RTM_ens1_case_7/lnd/hist/RTM_ens1_case_7.clm2.h0.2003-01.nc
# file8 =/glade/scratch/rfisher/archive/RTM_ens1_case_8/lnd/hist/RTM_ens1_case_8.clm2.h0.2003-01.nc
# file9 =/glade/scratch/rfisher/archive/RTM_ens1_case_9/lnd/hist/RTM_ens1_case_9.clm2.h0.2003-01.nc
# file10 =/glade/scratch/rfisher/archive/RTM_ens1_case_10/lnd/hist/RTM_ens1_case_10.clm2.h0.2003-01.nc
# file11 =/glade/scratch/rfisher/archive/RTM_ens1_case_11/lnd/hist/RTM_ens1_case_11.clm2.h0.2003-01.nc
# file12 =/glade/scratch/rfisher/archive/RTM_ens1_case_12/lnd/hist/RTM_ens1_case_12.clm2.h0.2003-01.nc
# file13 =/glade/scratch/rfisher/archive/RTM_ens1_case_13/lnd/hist/RTM_ens1_case_13.clm2.h0.2003-01.nc
# file14 =/glade/scratch/rfisher/archive/RTM_ens1_case_14/lnd/hist/RTM_ens1_case_14.clm2.h0.2003-01.nc
# file15 =/glade/scratch/rfisher/archive/RTM_ens1_case_15/lnd/hist/RTM_ens1_case_15.clm2.h0.2003-01.nc
# file16 =/glade/scratch/rfisher/archive/RTM_ens1_case_16/lnd/hist/RTM_ens1_case_16.clm2.h0.2003-01.nc
# end

# %%
#print(allvars)

# %% [markdown]
# ####  ANALYSIS: Save data in netcdf file just incase

# %%
outfile=figpath+'/dataout.nc' 
dsc.to_netcdf(outfile)
os.listdir(figpath)
# Out:
# ['dataout.nc']

# %% [markdown]
# ####  ANALYSIS:  Make a function to plot relative differences between runs

# %%
def make_diff_figure(dsc,v,rel,conv,ncases,parameter_list):   
    fig = plt.figure()
    plt.rcParams['figure.figsize'] = [27,7]
    fig.subplots_adjust(hspace=0.3, wspace=0.2)
    vs=range(1,ncases+1)
    nrow=2
    ncol=(ncases+1) // 2
    count=1
    var_0=dsc[vars[v]].isel(ens=0)
    defm=np.multiply(np.mean(var_0,0),conv)
    for i in vs:
        index=((count+1) % 2)*ncol + ((count+1) // 2)
        p=((count+1) // 2)-1
        ax = fig.add_subplot(nrow, ncol, index)
        var_i=dsc[vars[v]].isel(ens=i)
        mod=np.multiply(np.mean(var_i,0),conv)
        
        delt=mod-defm
        plt1=delt.plot(cmap='RdYlBu')
                  
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if((count+1) % 2==0):
            ex=' x'+str(min_delta[p])
        else:
            ex=' x'+str(max_delta[p])
        ax.set_title(str(parameter_label[(((count+1) // 2))-1]+ex))
        count=count+1
        fig.canvas.draw()
       # time.sleep(1)

# %%
make_diff_figure(dsc,0,rel,3600*365*24,ncases,parameter_list)

# %%
conv=1
make_diff_figure(dsc,1,rel,conv,ncases,parameter_list)

# %%
conv=1
make_diff_figure(dsc,2,rel,conv,ncases,parameter_list)

# %%
conv=1
make_diff_figure(dsc,3,rel,conv,ncases,parameter_list)

# %%
# !cat '/glade/work/rfisher/git/ctsmsep22/cime/scripts//RTM_ens1/RTM_ens1_case_12/user_nl_clm'
